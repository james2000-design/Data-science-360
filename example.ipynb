# %%
# x =3
# y= 6
# y-x
# print(y-x)
# print(x+y)


10 == 20/2
print(10 == 20/2)
10 != 10
x = 10
y =25

if x > 3 and y >13:
    print('Both conditions are correct')


if x <= 3 or y <= 13:
    print('At least one condition is correct')

def compare_numbers(y):
    if y > 5:
        return "Greater"
    elif y < 0:
        return "Negative"
    elif y < 5 :
        return "Less"
    else :
        return "Equal"
    
compare_numbers(-1)
compare_numbers(9)

range(1,11)
list(range(1,11))


prices = {
    "box_of_spagetti":4,
    "lasagna":5,
    "hamburger":2
}
quantity = {
    "box_of_spagetti":6,
    "lasagna":10,
    "hamburger":0
}

money_spent = 0

for i in prices:
    if prices[i]<5:
        money_spent +=  prices[i]*quantity[i]
    print(money_spent)
# Out:
# True
# Both conditions are correct
# 24
# 24
# 24
